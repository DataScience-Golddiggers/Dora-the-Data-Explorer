# %% [markdown]
# # XGBoost v2 - Binary Classification
#
# **Obiettivo:** Classificazione binaria IncidentGrade (1=TruePositive, 0=FalsePositive/BenignPositive)
#
# **Dataset:** Processed v3 con SmoothedRisk, GeoLoc_freq, frequency encoding
#
# **Metriche:** ROC AUC, Accuracy, Precision, Recall, F1-Score
#
# **Pipeline:**
# 1. Caricamento dati processed_v3
# 2. Training XGBoost (binary classification)
# 3. Valutazione e cross-validation
# 4. ROC Curve e AUC
# 5. Feature importance
# 6. Salvataggio modello in models/xgboost_v2/

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    roc_auc_score,
    roc_curve,
    accuracy_score,
    f1_score,
    precision_score,
    recall_score
)
from sklearn.model_selection import cross_val_score, StratifiedKFold
import pickle
import os
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('whitegrid')

print("Librerie importate con successo!")
# Out:
# Librerie importate con successo!

# %% [markdown]
# ## 2. Caricamento Dati

# %%
print("Caricamento dataset processed_v3...")

X_train = pd.read_csv('../data/processed_v3/X_train.csv')
X_test = pd.read_csv('../data/processed_v3/X_test.csv')
y_train = pd.read_csv('../data/processed_v3/y_train.csv')['BinaryIncidentGrade']
y_test = pd.read_csv('../data/processed_v3/y_test.csv')['BinaryIncidentGrade']

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"\nDistribuzione y_train:")
print(y_train.value_counts(normalize=True))
print(f"\nDistribuzione y_test:")
print(y_test.value_counts(normalize=True))
# Out:
# Caricamento dataset processed_v3...
# X_train: (314230, 43)
# X_test: (134671, 43)
#
# Distribuzione y_train:
# BinaryIncidentGrade
# 0    0.78701
# 1    0.21299
# Name: proportion, dtype: float64
#
# Distribuzione y_test:
# BinaryIncidentGrade
# 0    0.787007
# 1    0.212993
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3. Training XGBoost (Binary Classification)

# %%
print("Training XGBoost per classificazione binaria...\n")

# Calcola scale_pos_weight per gestire imbalance
neg_count = (y_train == 0).sum()
pos_count = (y_train == 1).sum()
scale_pos_weight = neg_count / pos_count

print(f"Class imbalance: {neg_count} negativi vs {pos_count} positivi")
print(f"scale_pos_weight: {scale_pos_weight:.2f}\n")

model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    max_depth=6,
    learning_rate=0.1,
    n_estimators=200,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=scale_pos_weight,
    random_state=42,
    tree_method='hist',
    n_jobs=-1
)

model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)

print("\nTraining completato!")
# Out:
# Training XGBoost per classificazione binaria...
#
# Class imbalance: 247302 negativi vs 66928 positivi
# scale_pos_weight: 3.70
#
# [0]	validation_0-auc:0.86467
# [1]	validation_0-auc:0.86614
# [2]	validation_0-auc:0.87292
# [3]	validation_0-auc:0.87350
# [4]	validation_0-auc:0.87390
# [5]	validation_0-auc:0.87488
# [6]	validation_0-auc:0.87552
# [7]	validation_0-auc:0.87588
# [8]	validation_0-auc:0.87760
# [9]	validation_0-auc:0.87810
# [10]	validation_0-auc:0.87876
# [11]	validation_0-auc:0.87894
# [12]	validation_0-auc:0.87925
# [13]	validation_0-auc:0.87930
# [14]	validation_0-auc:0.87955
# [15]	validation_0-auc:0.87994
# [16]	validation_0-auc:0.88035
# [17]	validation_0-auc:0.88064
# [18]	validation_0-auc:0.88081
# [19]	validation_0-auc:0.88130
# [20]	validation_0-auc:0.88149
# [21]	validation_0-auc:0.88196
# [22]	validation_0-auc:0.88216
# [23]	validation_0-auc:0.88255
# [24]	validation_0-auc:0.88291
# [25]	validation_0-auc:0.88312
# [26]	validation_0-auc:0.88345
# [27]	validation_0-auc:0.88373
# [28]	validation_0-auc:0.88387
# [29]	validation_0-auc:0.88405
# [30]	validation_0-auc:0.88442
# [31]	validation_0-auc:0.88459
# [32]	validation_0-auc:0.88455
# [33]	validation_0-auc:0.88475
# [34]	validation_0-auc:0.88493
# [35]	validation_0-auc:0.88500
# [36]	validation_0-auc:0.88509
# [37]	validation_0-auc:0.88529
# [38]	validation_0-auc:0.88547
# [39]	validation_0-auc:0.88573
# [40]	validation_0-auc:0.88588
# [41]	validation_0-auc:0.88597
# [42]	validation_0-auc:0.88598
# [43]	validation_0-auc:0.88609
# [44]	validation_0-auc:0.88618
# [45]	validation_0-auc:0.88626
# [46]	validation_0-auc:0.88636
# [47]	validation_0-auc:0.88634
# [48]	validation_0-auc:0.88652
# [49]	validation_0-auc:0.88658
# [50]	validation_0-auc:0.88687
# [51]	validation_0-auc:0.88702
# [52]	validation_0-auc:0.88711
# [53]	validation_0-auc:0.88715
# [54]	validation_0-auc:0.88741
# [55]	validation_0-auc:0.88746
# [56]	validation_0-auc:0.88748
# [57]	validation_0-auc:0.88771
# [58]	validation_0-auc:0.88771
# [59]	validation_0-auc:0.88778
# [60]	validation_0-auc:0.88781
# [61]	validation_0-auc:0.88803
# [62]	validation_0-auc:0.88810
# [63]	validation_0-auc:0.88823
# [64]	validation_0-auc:0.88839
# [65]	validation_0-auc:0.88850
# [66]	validation_0-auc:0.88860
# [67]	validation_0-auc:0.88862
# [68]	validation_0-auc:0.88895
# [69]	validation_0-auc:0.88897
# [70]	validation_0-auc:0.88919
# [71]	validation_0-auc:0.88935
# [72]	validation_0-auc:0.88960
# [73]	validation_0-auc:0.88979
# [74]	validation_0-auc:0.88983
# [75]	validation_0-auc:0.88987
# [76]	validation_0-auc:0.89003
# [77]	validation_0-auc:0.89017
# [78]	validation_0-auc:0.89017
# [79]	validation_0-auc:0.89042
# [80]	validation_0-auc:0.89049
# [81]	validation_0-auc:0.89053
# [82]	validation_0-auc:0.89056
# [83]	validation_0-auc:0.89078
# [84]	validation_0-auc:0.89102
# [85]	validation_0-auc:0.89122
# [86]	validation_0-auc:0.89136
# [87]	validation_0-auc:0.89155
# [88]	validation_0-auc:0.89155
# [89]	validation_0-auc:0.89162
# [90]	validation_0-auc:0.89193
# [91]	validation_0-auc:0.89195
# [92]	validation_0-auc:0.89200
# [93]	validation_0-auc:0.89222
# [94]	validation_0-auc:0.89225
# [95]	validation_0-auc:0.89225
# [96]	validation_0-auc:0.89236
# [97]	validation_0-auc:0.89242
# [98]	validation_0-auc:0.89242
# [99]	validation_0-auc:0.89262
# [100]	validation_0-auc:0.89267
# [101]	validation_0-auc:0.89275
# [102]	validation_0-auc:0.89285
# [103]	validation_0-auc:0.89304
# [104]	validation_0-auc:0.89320
# [105]	validation_0-auc:0.89336
# [106]	validation_0-auc:0.89365
# [107]	validation_0-auc:0.89368
# [108]	validation_0-auc:0.89382
# [109]	validation_0-auc:0.89402
# [110]	validation_0-auc:0.89416
# [111]	validation_0-auc:0.89416
# [112]	validation_0-auc:0.89415
# [113]	validation_0-auc:0.89419
# [114]	validation_0-auc:0.89428
# [115]	validation_0-auc:0.89454
# [116]	validation_0-auc:0.89482
# [117]	validation_0-auc:0.89483
# [118]	validation_0-auc:0.89495
# [119]	validation_0-auc:0.89496
# [120]	validation_0-auc:0.89510
# [121]	validation_0-auc:0.89513
# [122]	validation_0-auc:0.89519
# [123]	validation_0-auc:0.89522
# [124]	validation_0-auc:0.89523
# [125]	validation_0-auc:0.89527
# [126]	validation_0-auc:0.89527
# [127]	validation_0-auc:0.89529
# [128]	validation_0-auc:0.89532
# [129]	validation_0-auc:0.89548
# [130]	validation_0-auc:0.89551
# [131]	validation_0-auc:0.89552
# [132]	validation_0-auc:0.89552
# [133]	validation_0-auc:0.89567
# [134]	validation_0-auc:0.89579
# [135]	validation_0-auc:0.89583
# [136]	validation_0-auc:0.89592
# [137]	validation_0-auc:0.89604
# [138]	validation_0-auc:0.89605
# [139]	validation_0-auc:0.89611
# [140]	validation_0-auc:0.89622
# [141]	validation_0-auc:0.89630
# [142]	validation_0-auc:0.89639
# [143]	validation_0-auc:0.89650
# [144]	validation_0-auc:0.89657
# [145]	validation_0-auc:0.89674
# [146]	validation_0-auc:0.89687
# [147]	validation_0-auc:0.89699
# [148]	validation_0-auc:0.89715
# [149]	validation_0-auc:0.89715
# [150]	validation_0-auc:0.89721
# [151]	validation_0-auc:0.89721
# [152]	validation_0-auc:0.89720
# [153]	validation_0-auc:0.89723
# [154]	validation_0-auc:0.89725
# [155]	validation_0-auc:0.89727
# [156]	validation_0-auc:0.89748
# [157]	validation_0-auc:0.89750
# [158]	validation_0-auc:0.89755
# [159]	validation_0-auc:0.89760
# [160]	validation_0-auc:0.89759
# [161]	validation_0-auc:0.89762
# [162]	validation_0-auc:0.89764
# [163]	validation_0-auc:0.89765
# [164]	validation_0-auc:0.89767
# [165]	validation_0-auc:0.89769
# [166]	validation_0-auc:0.89770
# [167]	validation_0-auc:0.89773
# [168]	validation_0-auc:0.89776
# [169]	validation_0-auc:0.89780
# [170]	validation_0-auc:0.89791
# [171]	validation_0-auc:0.89795
# [172]	validation_0-auc:0.89806
# [173]	validation_0-auc:0.89809
# [174]	validation_0-auc:0.89812
# [175]	validation_0-auc:0.89812
# [176]	validation_0-auc:0.89825
# [177]	validation_0-auc:0.89830
# [178]	validation_0-auc:0.89831
# [179]	validation_0-auc:0.89831
# [180]	validation_0-auc:0.89830
# [181]	validation_0-auc:0.89836
# [182]	validation_0-auc:0.89836
# [183]	validation_0-auc:0.89837
# [184]	validation_0-auc:0.89843
# [185]	validation_0-auc:0.89843
# [186]	validation_0-auc:0.89848
# [187]	validation_0-auc:0.89851
# [188]	validation_0-auc:0.89859
# [189]	validation_0-auc:0.89860
# [190]	validation_0-auc:0.89861
# [191]	validation_0-auc:0.89862
# [192]	validation_0-auc:0.89869
# [193]	validation_0-auc:0.89872
# [194]	validation_0-auc:0.89876
# [195]	validation_0-auc:0.89876
# [196]	validation_0-auc:0.89878
# [197]	validation_0-auc:0.89879
# [198]	validation_0-auc:0.89880
# [199]	validation_0-auc:0.89882
#
# Training completato!

# %% [markdown]
# ## 4. Valutazione Performance

# %%
# Predizioni
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]

print("=" * 70)
print("PERFORMANCE TEST SET")
print("=" * 70)

print("\nClassification Report:")
print(classification_report(
    y_test, y_pred,
    target_names=['Non-TP (0)', 'TruePositive (1)'],
    digits=4
))

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print(f"\nACCURACY:          {accuracy:.4f}")
print(f"PRECISION:         {precision:.4f}")
print(f"RECALL:            {recall:.4f}")
print(f"F1-SCORE:          {f1:.4f}")
print(f"ROC AUC:           {roc_auc:.4f} ⭐")
# Out:
# ======================================================================
# PERFORMANCE TEST SET
# ======================================================================
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#       Non-TP (0)     0.9283    0.8422    0.8831    105987
# TruePositive (1)     0.5657    0.7598    0.6485     28684
#
#         accuracy                         0.8246    134671
#        macro avg     0.7470    0.8010    0.7658    134671
#     weighted avg     0.8511    0.8246    0.8332    134671
#
#
# ACCURACY:          0.8246
# PRECISION:         0.5657
# RECALL:            0.7598
# F1-SCORE:          0.6485
# ROC AUC:           0.8988 ⭐

# %% [markdown]
# ## 5. Confusion Matrix

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-TP (0)', 'TruePositive (1)'],
            yticklabels=['Non-TP (0)', 'TruePositive (1)'],
            ax=axes[0])
axes[0].set_title('Confusion Matrix (Counts)')
axes[0].set_ylabel('True Label')
axes[0].set_xlabel('Predicted Label')

sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=['Non-TP (0)', 'TruePositive (1)'],
            yticklabels=['Non-TP (0)', 'TruePositive (1)'],
            ax=axes[1])
axes[1].set_title('Confusion Matrix (Normalized)')
axes[1].set_ylabel('True Label')
axes[1].set_xlabel('Predicted Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. ROC Curve

# %%
# Calcola ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(10, 8))

plt.plot(fpr, tpr, color='blue', lw=2,
         label=f'XGBoost v2 (AUC = {roc_auc:.4f})')

# Plot diagonal (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=1, label='Random Classifier')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve - XGBoost Binary Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=11)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\n📊 ROC AUC Score: {roc_auc:.4f}")
# Out:
# 📊 ROC AUC Score: 0.8988

# %% [markdown]
# ## 7. Cross-Validation

# %%
print("Esecuzione 5-Fold Stratified Cross-Validation...\n")

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Cross-validation con ROC AUC
cv_scores = cross_val_score(
    model, X_train, y_train,
    cv=skf,
    scoring='roc_auc',
    n_jobs=-1
)

print(f"Cross-Validation ROC AUC Scores:")
for i, score in enumerate(cv_scores, 1):
    print(f"  Fold {i}: {score:.4f}")

print(f"\nMedia:  {cv_scores.mean():.4f}")
print(f"Std:    {cv_scores.std():.4f}")
# Out:
# Esecuzione 5-Fold Stratified Cross-Validation...
#
# Cross-Validation ROC AUC Scores:
#   Fold 1: 0.8980
#   Fold 2: 0.9013
#   Fold 3: 0.8985
#   Fold 4: 0.8991
#   Fold 5: 0.8989
#
# Media:  0.8991
# Std:    0.0011

# %% [markdown]
# ## 8. Feature Importance

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': model.feature_importances_
}).sort_values('Importance', ascending=False)

print("Top 30 Features più importanti:")
print(feature_importance.head(30).to_string(index=False))
# Out:
# Top 30 Features più importanti:
#                       Feature  Importance
#                     T1078_sum    0.258093
#              SmoothedRisk_avg    0.223092
#      EvidenceRole_Related_sum    0.052454
#               GeoLoc_freq_avg    0.046856
#         LastVerdict_freq_mean    0.045079
#          EntityType_freq_mean    0.032825
#               Roles_freq_mean    0.028504
#            Category_freq_mean    0.021544
#    SuspicionLevel_Missing_sum    0.018517
#              Duration_seconds    0.015307
#                     T1106_sum    0.014895
#                     NumAlerts    0.014447
#                     T1046_sum    0.014178
#                  NumEvidences    0.013136
# SuspicionLevel_Suspicious_sum    0.011390
#                 IsWeekend_max    0.010943
#                month_get_mode    0.010530
#       ActionGrouped_freq_mean    0.010081
#        ResourceType_freq_mean    0.009823
#        ThreatFamily_freq_mean    0.009459
#                     T1110_sum    0.009056
#   AntispamDirection_freq_mean    0.008795
#                     T1568_sum    0.008764
#                     T1008_sum    0.008479
#              weekday_get_mode    0.008337
#      ActionGranular_freq_mean    0.007036
#                     T1566_sum    0.006920
#                     T1133_sum    0.006898
#                     T1048_sum    0.006806
#                     Hour_Last    0.005912

# %%
# Plot top features
plt.figure(figsize=(12, 10))
top_n = 25
top_features = feature_importance.head(top_n)

plt.barh(range(top_n), top_features['Importance'], color='steelblue')
plt.yticks(range(top_n), top_features['Feature'])
plt.xlabel('Importance', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.title(f'Top {top_n} Feature Importance - XGBoost v2', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Salvataggio Modello

# %%
# Crea cartella per XGBoost v2
model_dir = '../models/xgboost_v2'
os.makedirs(model_dir, exist_ok=True)

# Salva modello
model.save_model(f'{model_dir}/model.json')

with open(f'{model_dir}/model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Salva feature importance
feature_importance.to_csv(f'{model_dir}/feature_importance.csv', index=False)

# Salva metriche complete
metrics = {
    'model_name': 'XGBoost_v2_Binary',
    'timestamp': datetime.now().isoformat(),
    'dataset_version': 'processed_v3',
    'target': 'BinaryIncidentGrade (0=Non-TP, 1=TP)',
    'test_accuracy': float(accuracy),
    'test_precision': float(precision),
    'test_recall': float(recall),
    'test_f1_score': float(f1),
    'test_roc_auc': float(roc_auc),
    'cv_roc_auc_mean': float(cv_scores.mean()),
    'cv_roc_auc_std': float(cv_scores.std()),
    'n_features': int(X_train.shape[1]),
    'n_train_samples': int(len(X_train)),
    'n_test_samples': int(len(X_test)),
    'class_distribution_train': {
        'class_0': int((y_train == 0).sum()),
        'class_1': int((y_train == 1).sum())
    },
    'hyperparameters': {
        'objective': 'binary:logistic',
        'max_depth': model.max_depth,
        'learning_rate': float(model.learning_rate),
        'n_estimators': model.n_estimators,
        'subsample': float(model.subsample),
        'colsample_bytree': float(model.colsample_bytree),
        'scale_pos_weight': float(scale_pos_weight)
    },
    'top_10_features': feature_importance.head(10)[['Feature', 'Importance']].to_dict('records')
}

with open(f'{model_dir}/metrics.json', 'w') as f:
    json.dump(metrics, f, indent=2)

print(f"\n{'='*70}")
print(f"Modello salvato in {model_dir}/")
print(f"{'='*70}")
print("  ✓ model.json")
print("  ✓ model.pkl")
print("  ✓ feature_importance.csv")
print("  ✓ metrics.json")
print(f"\n📊 ROC AUC Test: {roc_auc:.4f}")
print(f"📊 ROC AUC CV:   {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
# Out:
# ======================================================================
# Modello salvato in ../models/xgboost_v2/
# ======================================================================
#   ✓ model.json
#   ✓ model.pkl
#   ✓ feature_importance.csv
#   ✓ metrics.json
#
# 📊 ROC AUC Test: 0.8988
# 📊 ROC AUC CV:   0.8991 ± 0.0011

# %% [markdown]
# ## Summary
#
# **Modello:** XGBoost Binary Classifier
# **Dataset:** processed_v3 (SmoothedRisk, GeoLoc_freq, frequency encoding)
# **Target:** BinaryIncidentGrade (0=FalsePositive/BenignPositive, 1=TruePositive)
#
# **Features chiave del v3:**
# - SmoothedRisk (Bayesian smoothing per AlertTitle)
# - GeoLoc_freq (frequenza location)
# - Frequency encoding per colonne ad alta cardinalità
# - MITRE top 30 techniques
#
# **Metriche principali:**
# - ROC AUC (primary metric per binary classification)
# - Precision/Recall/F1 per valutare trade-off
# - Cross-validation per robustezza
