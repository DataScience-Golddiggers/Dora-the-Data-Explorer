# %% [markdown]
# # Modeling - XGBoost Classifier
#
# **Obiettivo:** Classificazione IncidentGrade (TruePositive, BenignPositive, FalsePositive)
#
# **Metrica:** Macro F1-Score
#
# **Pipeline:**
# 1. Caricamento dati
# 2. Training XGBoost
# 3. Valutazione e cross-validation
# 4. Feature importance
# 5. Salvataggio modello

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    f1_score,
    accuracy_score
)
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import pickle
import os
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('whitegrid')

print("Librerie importate con successo!")
# Out:
# Librerie importate con successo!

# %% [markdown]
# ## 2. Caricamento Dati

# %%
print("Caricamento dataset processati...")

X_train = pd.read_csv('../data/processed/X_train.csv')
X_test = pd.read_csv('../data/processed/X_test.csv')
y_train = pd.read_csv('../data/processed/y_train.csv')['IncidentGrade']
y_test = pd.read_csv('../data/processed/y_test.csv')['IncidentGrade']

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"\nDistribuzione y_train:\n{y_train.value_counts(normalize=True)}")
# Out:
# Caricamento dataset processati...
# X_train: (314230, 20)
# X_test: (134671, 20)
#
# Distribuzione y_train:
# IncidentGrade
# BenignPositive    0.485921
# FalsePositive     0.301088
# TruePositive      0.212990
# Name: proportion, dtype: float64

# %%
# Encoding target
le_target = LabelEncoder()
y_train_encoded = le_target.fit_transform(y_train)
y_test_encoded = le_target.transform(y_test)

print("Mapping label:")
for i, label in enumerate(le_target.classes_):
    print(f"  {label} -> {i}")
# Out:
# Mapping label:
#   BenignPositive -> 0
#   FalsePositive -> 1
#   TruePositive -> 2

# %% [markdown]
# ## 3. Training XGBoost

# %%
print("Training XGBoost...\n")

model = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=len(le_target.classes_),
    eval_metric='mlogloss',
    max_depth=6,
    learning_rate=0.1,
    n_estimators=200,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    tree_method='hist',
    n_jobs=-1
)

model.fit(
    X_train, y_train_encoded,
    eval_set=[(X_test, y_test_encoded)],
    verbose=True
)

print("Training completato!")
# Out:
# Training XGBoost...
#
# [0]	validation_0-mlogloss:1.04584
# [1]	validation_0-mlogloss:1.02678
# [2]	validation_0-mlogloss:1.01051
# [3]	validation_0-mlogloss:0.99646
# [4]	validation_0-mlogloss:0.98572
# [5]	validation_0-mlogloss:0.97722
# [6]	validation_0-mlogloss:0.96891
# [7]	validation_0-mlogloss:0.96057
# [8]	validation_0-mlogloss:0.95476
# [9]	validation_0-mlogloss:0.94822
# [10]	validation_0-mlogloss:0.94261
# [11]	validation_0-mlogloss:0.93774
# [12]	validation_0-mlogloss:0.93475
# [13]	validation_0-mlogloss:0.93092
# [14]	validation_0-mlogloss:0.92740
# [15]	validation_0-mlogloss:0.92492
# [16]	validation_0-mlogloss:0.92197
# [17]	validation_0-mlogloss:0.91946
# [18]	validation_0-mlogloss:0.91794
# [19]	validation_0-mlogloss:0.91628
# [20]	validation_0-mlogloss:0.91447
# [21]	validation_0-mlogloss:0.91275
# [22]	validation_0-mlogloss:0.91161
# [23]	validation_0-mlogloss:0.91078
# [24]	validation_0-mlogloss:0.90971
# [25]	validation_0-mlogloss:0.90855
# [26]	validation_0-mlogloss:0.90757
# [27]	validation_0-mlogloss:0.90675
# [28]	validation_0-mlogloss:0.90610
# [29]	validation_0-mlogloss:0.90551
# [30]	validation_0-mlogloss:0.90479
# [31]	validation_0-mlogloss:0.90416
# [32]	validation_0-mlogloss:0.90374
# [33]	validation_0-mlogloss:0.90321
# [34]	validation_0-mlogloss:0.90276
# [35]	validation_0-mlogloss:0.90232
# [36]	validation_0-mlogloss:0.90191
# [37]	validation_0-mlogloss:0.90150
# [38]	validation_0-mlogloss:0.90118
# [39]	validation_0-mlogloss:0.90084
# [40]	validation_0-mlogloss:0.90062
# [41]	validation_0-mlogloss:0.90044
# [42]	validation_0-mlogloss:0.90016
# [43]	validation_0-mlogloss:0.89993
# [44]	validation_0-mlogloss:0.89981
# [45]	validation_0-mlogloss:0.89966
# [46]	validation_0-mlogloss:0.89946
# [47]	validation_0-mlogloss:0.89932
# [48]	validation_0-mlogloss:0.89912
# [49]	validation_0-mlogloss:0.89896
# [50]	validation_0-mlogloss:0.89889
# [51]	validation_0-mlogloss:0.89879
# [52]	validation_0-mlogloss:0.89862
# [53]	validation_0-mlogloss:0.89845
# [54]	validation_0-mlogloss:0.89827
# [55]	validation_0-mlogloss:0.89815
# [56]	validation_0-mlogloss:0.89807
# [57]	validation_0-mlogloss:0.89794
# [58]	validation_0-mlogloss:0.89780
# [59]	validation_0-mlogloss:0.89775
# [60]	validation_0-mlogloss:0.89762
# [61]	validation_0-mlogloss:0.89754
# [62]	validation_0-mlogloss:0.89744
# [63]	validation_0-mlogloss:0.89736
# [64]	validation_0-mlogloss:0.89727
# [65]	validation_0-mlogloss:0.89721
# [66]	validation_0-mlogloss:0.89718
# [67]	validation_0-mlogloss:0.89709
# [68]	validation_0-mlogloss:0.89700
# [69]	validation_0-mlogloss:0.89698
# [70]	validation_0-mlogloss:0.89686
# [71]	validation_0-mlogloss:0.89680
# [72]	validation_0-mlogloss:0.89668
# [73]	validation_0-mlogloss:0.89667
# [74]	validation_0-mlogloss:0.89663
# [75]	validation_0-mlogloss:0.89656
# [76]	validation_0-mlogloss:0.89656
# [77]	validation_0-mlogloss:0.89652
# [78]	validation_0-mlogloss:0.89647
# [79]	validation_0-mlogloss:0.89644
# [80]	validation_0-mlogloss:0.89638
# [81]	validation_0-mlogloss:0.89635
# [82]	validation_0-mlogloss:0.89633
# [83]	validation_0-mlogloss:0.89631
# [84]	validation_0-mlogloss:0.89627
# [85]	validation_0-mlogloss:0.89624
# [86]	validation_0-mlogloss:0.89620
# [87]	validation_0-mlogloss:0.89615
# [88]	validation_0-mlogloss:0.89614
# [89]	validation_0-mlogloss:0.89612
# [90]	validation_0-mlogloss:0.89607
# [91]	validation_0-mlogloss:0.89599
# [92]	validation_0-mlogloss:0.89597
# [93]	validation_0-mlogloss:0.89596
# [94]	validation_0-mlogloss:0.89595
# [95]	validation_0-mlogloss:0.89593
# [96]	validation_0-mlogloss:0.89591
# [97]	validation_0-mlogloss:0.89585
# [98]	validation_0-mlogloss:0.89583
# [99]	validation_0-mlogloss:0.89582
# [100]	validation_0-mlogloss:0.89572
# [101]	validation_0-mlogloss:0.89571
# [102]	validation_0-mlogloss:0.89570
# [103]	validation_0-mlogloss:0.89564
# [104]	validation_0-mlogloss:0.89563
# [105]	validation_0-mlogloss:0.89562
# [106]	validation_0-mlogloss:0.89559
# [107]	validation_0-mlogloss:0.89552
# [108]	validation_0-mlogloss:0.89551
# [109]	validation_0-mlogloss:0.89549
# [110]	validation_0-mlogloss:0.89546
# [111]	validation_0-mlogloss:0.89546
# [112]	validation_0-mlogloss:0.89543
# [113]	validation_0-mlogloss:0.89543
# [114]	validation_0-mlogloss:0.89540
# [115]	validation_0-mlogloss:0.89538
# [116]	validation_0-mlogloss:0.89533
# [117]	validation_0-mlogloss:0.89525
# [118]	validation_0-mlogloss:0.89523
# [119]	validation_0-mlogloss:0.89521
# [120]	validation_0-mlogloss:0.89519
# [121]	validation_0-mlogloss:0.89518
# [122]	validation_0-mlogloss:0.89518
# [123]	validation_0-mlogloss:0.89517
# [124]	validation_0-mlogloss:0.89515
# [125]	validation_0-mlogloss:0.89515
# [126]	validation_0-mlogloss:0.89514
# [127]	validation_0-mlogloss:0.89514
# [128]	validation_0-mlogloss:0.89512
# [129]	validation_0-mlogloss:0.89513
# [130]	validation_0-mlogloss:0.89514
# [131]	validation_0-mlogloss:0.89514
# [132]	validation_0-mlogloss:0.89514
# [133]	validation_0-mlogloss:0.89512
# [134]	validation_0-mlogloss:0.89510
# [135]	validation_0-mlogloss:0.89507
# [136]	validation_0-mlogloss:0.89507
# [137]	validation_0-mlogloss:0.89507
# [138]	validation_0-mlogloss:0.89506
# [139]	validation_0-mlogloss:0.89507
# [140]	validation_0-mlogloss:0.89507
# [141]	validation_0-mlogloss:0.89507
# [142]	validation_0-mlogloss:0.89507
# [143]	validation_0-mlogloss:0.89506
# [144]	validation_0-mlogloss:0.89504
# [145]	validation_0-mlogloss:0.89504
# [146]	validation_0-mlogloss:0.89501
# [147]	validation_0-mlogloss:0.89499
# [148]	validation_0-mlogloss:0.89494
# [149]	validation_0-mlogloss:0.89494
# [150]	validation_0-mlogloss:0.89495
# [151]	validation_0-mlogloss:0.89494
# [152]	validation_0-mlogloss:0.89493
# [153]	validation_0-mlogloss:0.89492
# [154]	validation_0-mlogloss:0.89491
# [155]	validation_0-mlogloss:0.89490
# [156]	validation_0-mlogloss:0.89491
# [157]	validation_0-mlogloss:0.89491
# [158]	validation_0-mlogloss:0.89491
# [159]	validation_0-mlogloss:0.89490
# [160]	validation_0-mlogloss:0.89490
# [161]	validation_0-mlogloss:0.89489
# [162]	validation_0-mlogloss:0.89486
# [163]	validation_0-mlogloss:0.89484
# [164]	validation_0-mlogloss:0.89485
# [165]	validation_0-mlogloss:0.89481
# [166]	validation_0-mlogloss:0.89479
# [167]	validation_0-mlogloss:0.89479
# [168]	validation_0-mlogloss:0.89479
# [169]	validation_0-mlogloss:0.89479
# [170]	validation_0-mlogloss:0.89479
# [171]	validation_0-mlogloss:0.89478
# [172]	validation_0-mlogloss:0.89476
# [173]	validation_0-mlogloss:0.89475
# [174]	validation_0-mlogloss:0.89474
# [175]	validation_0-mlogloss:0.89473
# [176]	validation_0-mlogloss:0.89473
# [177]	validation_0-mlogloss:0.89473
# [178]	validation_0-mlogloss:0.89473
# [179]	validation_0-mlogloss:0.89470
# [180]	validation_0-mlogloss:0.89468
# [181]	validation_0-mlogloss:0.89467
# [182]	validation_0-mlogloss:0.89467
# [183]	validation_0-mlogloss:0.89467
# [184]	validation_0-mlogloss:0.89468
# [185]	validation_0-mlogloss:0.89467
# [186]	validation_0-mlogloss:0.89467
# [187]	validation_0-mlogloss:0.89468
# [188]	validation_0-mlogloss:0.89468
# [189]	validation_0-mlogloss:0.89467
# [190]	validation_0-mlogloss:0.89467
# [191]	validation_0-mlogloss:0.89467
# [192]	validation_0-mlogloss:0.89468
# [193]	validation_0-mlogloss:0.89466
# [194]	validation_0-mlogloss:0.89464
# [195]	validation_0-mlogloss:0.89465
# [196]	validation_0-mlogloss:0.89464
# [197]	validation_0-mlogloss:0.89463
# [198]	validation_0-mlogloss:0.89464
# [199]	validation_0-mlogloss:0.89464
# Training completato!

# %% [markdown]
# ## 4. Valutazione

# %%
y_pred = model.predict(X_test)

print("=" * 70)
print("PERFORMANCE TEST SET")
print("=" * 70)

print("\nClassification Report:")
print(classification_report(
    y_test_encoded, y_pred,
    target_names=le_target.classes_,
    digits=4
))

accuracy = accuracy_score(y_test_encoded, y_pred)
macro_f1 = f1_score(y_test_encoded, y_pred, average='macro')

print(f"\nACCURACY:          {accuracy:.4f}")
print(f"MACRO F1-SCORE:    {macro_f1:.4f} ⭐")
# Out:
# ======================================================================
# PERFORMANCE TEST SET
# ======================================================================
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# BenignPositive     0.6149    0.7789    0.6873     65440
#  FalsePositive     0.5473    0.5502    0.5487     40547
#   TruePositive     0.5521    0.2121    0.3065     28684
#
#       accuracy                         0.5893    134671
#      macro avg     0.5714    0.5137    0.5142    134671
#   weighted avg     0.5812    0.5893    0.5645    134671
#
#
# ACCURACY:          0.5893
# MACRO F1-SCORE:    0.5142 ⭐

# %%
# Confusion Matrix
cm = confusion_matrix(y_test_encoded, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le_target.classes_,
            yticklabels=le_target.classes_,
            ax=axes[0])
axes[0].set_title('Confusion Matrix')
axes[0].set_ylabel('True Label')
axes[0].set_xlabel('Predicted Label')

sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=le_target.classes_,
            yticklabels=le_target.classes_,
            ax=axes[1])
axes[1].set_title('Confusion Matrix (Normalizzata)')
axes[1].set_ylabel('True Label')
axes[1].set_xlabel('Predicted Label')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Ottieni probabilità di predizione
y_pred_proba = model.predict_proba(X_test)

# Binarizza le label per ROC multi-class (One-vs-Rest)
y_test_bin = label_binarize(y_test_encoded, classes=[0, 1, 2])
n_classes = y_test_bin.shape[1]

# Calcola ROC curve e AUC per ogni classe
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Micro-average ROC curve
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), y_pred_proba.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

print("ROC AUC Scores:")
for i, class_name in enumerate(le_target.classes_):
    print(f"  {class_name}: {roc_auc[i]:.4f}")
print(f"  Micro-average: {roc_auc['micro']:.4f}")
# Out:
# ROC AUC Scores:
#   BenignPositive: 0.7300
#   FalsePositive: 0.7673
#   TruePositive: 0.7011
#   Micro-average: 0.7689

# %% [markdown]
# ## 4.1 ROC Curve (One-vs-Rest)

# %%
# Plot ROC curves
plt.figure(figsize=(10, 8))

colors = ['blue', 'red', 'green']
for i in range(2):
    plt.plot(fpr[i], tpr[i], color=colors[i], lw=2,
             label=f'{le_target.classes_[i]} (AUC = {roc_auc[i]:.4f})')

# Plot micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], color='deeppink', linestyle='--', lw=2,
         label=f'Micro-average (AUC = {roc_auc["micro"]:.4f})')

# Plot diagonal line (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=1, label='Random Classifier')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - XGBoost (One-vs-Rest)')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Cross-Validation

# %%
print("Esecuzione 5-Fold Cross-Validation...\n")

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(
    model, X_train, y_train_encoded,
    cv=skf,
    scoring='f1_macro',
    n_jobs=-1
)

print(f"Cross-Validation Macro F1 Scores:")
for i, score in enumerate(cv_scores, 1):
    print(f"  Fold {i}: {score:.4f}")

print(f"\nMedia:  {cv_scores.mean():.4f}")
print(f"Std:    {cv_scores.std():.4f}")
# Out:
# Esecuzione 5-Fold Cross-Validation...
#
# Cross-Validation Macro F1 Scores:
#   Fold 1: 0.5082
#   Fold 2: 0.5129
#   Fold 3: 0.5151
#   Fold 4: 0.5115
#   Fold 5: 0.5124
#
# Media:  0.5120
# Std:    0.0022

# %% [markdown]
# ## 6. Feature Importance

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': model.feature_importances_
}).sort_values('Importance', ascending=False)

print("Top 20 Features più importanti:")
print(feature_importance.head(20).to_string(index=False))
# Out:
# Top 20 Features più importanti:
#            Feature  Importance
#     NumWithVerdict    0.255539
#  Category_get_mode    0.223981
#       NumEvidences    0.119911
#   NumWithSuspicion    0.059027
#          NumAlerts    0.056636
#          Hour_Last    0.045082
# DayOfWeek_get_mode    0.035146
#     NumEntityTypes    0.034187
#      IsWeekend_max    0.030994
#         Hour_First    0.022791
#   Duration_seconds    0.019716
#           Hour_Avg    0.018053
#   NumEvidenceRoles    0.015594
#  MITRE_unknown_sum    0.012236
#    MITRE_T1566_sum    0.009782
#    MITRE_T1078_sum    0.009738
#    MITRE_T1110_sum    0.008937
#    MITRE_T1059_sum    0.007843
#   MITRE_n_rare_sum    0.007549
#    MITRE_T1003_sum    0.007259

# %%
# Plot top features
plt.figure(figsize=(12, 8))
top_n = 20
top_features = feature_importance.head(top_n)

plt.barh(range(top_n), top_features['Importance'], color='steelblue')
plt.yticks(range(top_n), top_features['Feature'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title(f'Top {top_n} Feature Importance')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Salvataggio Modello

# %%
# Crea cartella per XGBoost
model_dir = '../models/xgboost'
os.makedirs(model_dir, exist_ok=True)

# Salva modello
model.save_model(f'{model_dir}/model.json')

with open(f'{model_dir}/model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Salva label encoder
with open(f'{model_dir}/label_encoder.pkl', 'wb') as f:
    pickle.dump(le_target, f)

# Salva feature importance
feature_importance.to_csv(f'{model_dir}/feature_importance.csv', index=False)

# Salva metriche (inclusa ROC AUC)
metrics = {
    'model_name': 'XGBoost',
    'timestamp': datetime.now().isoformat(),
    'test_accuracy': float(accuracy),
    'test_macro_f1': float(macro_f1),
    'cv_macro_f1_mean': float(cv_scores.mean()),
    'cv_macro_f1_std': float(cv_scores.std()),
    'roc_auc_per_class': {le_target.classes_[i]: float(roc_auc[i]) for i in range(n_classes)},
    'roc_auc_micro': float(roc_auc['micro']),
    'n_features': int(X_train.shape[1]),
    'n_train_samples': int(len(X_train)),
    'n_test_samples': int(len(X_test)),
    'hyperparameters': {
        'max_depth': model.max_depth,
        'learning_rate': float(model.learning_rate),
        'n_estimators': model.n_estimators,
        'subsample': float(model.subsample),
        'colsample_bytree': float(model.colsample_bytree)
    }
}

with open(f'{model_dir}/metrics.json', 'w') as f:
    json.dump(metrics, f, indent=2)

print(f"Modello salvato in {model_dir}/")
print("  - model.json")
print("  - model.pkl")
print("  - label_encoder.pkl")
print("  - feature_importance.csv")
print("  - metrics.json")
# Out:
# Modello salvato in ../models/xgboost/
#   - model.json
#   - model.pkl
#   - label_encoder.pkl
#   - feature_importance.csv
#   - metrics.json
