# %% [markdown]
# # XGBoost v2 - Binary Classification
#
# **Obiettivo:** Classificazione binaria IncidentGrade (1=TruePositive, 0=FalsePositive/BenignPositive)
#
# **Dataset:** Processed v3 con SmoothedRisk, GeoLoc_freq, frequency encoding
#
# **Metriche:** ROC AUC, Accuracy, Precision, Recall, F1-Score
#
# **Pipeline:**
# 1. Caricamento dati processed_v3
# 2. Training XGBoost (binary classification)
# 3. Valutazione e cross-validation
# 4. ROC Curve e AUC
# 5. Feature importance
# 6. Salvataggio modello in models/xgboost_v2/

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    roc_auc_score,
    roc_curve,
    accuracy_score,
    f1_score,
    precision_score,
    recall_score
)
from sklearn.model_selection import cross_val_score, StratifiedKFold
import pickle
import os
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('whitegrid')

print("Librerie importate con successo!")
# Out:
# Librerie importate con successo!

# %% [markdown]
# ## 2. Caricamento Dati

# %%
print("Caricamento dataset processed_v4_hybrid...")

X_train = pd.read_csv('../data/processed_v4_hybrid/X_train.csv')
X_test = pd.read_csv('../data/processed_v4_hybrid/X_test.csv')
y_train = pd.read_csv('../data/processed_v4_hybrid/y_train.csv')['BinaryIncidentGrade']
y_test = pd.read_csv('../data/processed_v4_hybrid/y_test.csv')['BinaryIncidentGrade']

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"\nDistribuzione y_train:")
print(y_train.value_counts(normalize=True))
print(f"\nDistribuzione y_test:")
print(y_test.value_counts(normalize=True))
# Out:
# Caricamento dataset processed_v4_hybrid...
# X_train: (200784, 43)
# X_test: (134671, 43)
#
# Distribuzione y_train:
# BinaryIncidentGrade
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
# Distribuzione y_test:
# BinaryIncidentGrade
# 0    0.787007
# 1    0.212993
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

print("Creazione validation set (20% del training set)...\n")

# Split training in train e validation (stratificato)
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train, y_train,
    test_size=0.2,
    stratify=y_train,
    random_state=42
)

print(f"X_train_final: {X_train_final.shape}")
print(f"X_val:         {X_val.shape}")
print(f"X_test:        {X_test.shape}")

print(f"\nDistribuzione y_train_final:")
print(y_train_final.value_counts(normalize=True))
print(f"\nDistribuzione y_val:")
print(y_val.value_counts(normalize=True))

print("\n✅ Validation set creato. Verrà usato per monitorare il training.")
# Out:
# Creazione validation set (20% del training set)...
#
# X_train_final: (160627, 43)
# X_val:         (40157, 43)
# X_test:        (134671, 43)
#
# Distribuzione y_train_final:
# BinaryIncidentGrade
# 1    0.500003
# 0    0.499997
# Name: proportion, dtype: float64
#
# Distribuzione y_val:
# BinaryIncidentGrade
# 0    0.500012
# 1    0.499988
# Name: proportion, dtype: float64
#
# ✅ Validation set creato. Verrà usato per monitorare il training.

# %% [markdown]
# ## 2.1. Creazione Validation Set

# %% [markdown]
# ## 3. Training XGBoost (Binary Classification)

# %%
print("Training XGBoost per classificazione binaria...\n")

# Calcola scale_pos_weight per gestire imbalance (su train_final)
neg_count = (y_train_final == 0).sum()
pos_count = (y_train_final == 1).sum()
scale_pos_weight = neg_count / pos_count

print(f"Class imbalance: {neg_count} negativi vs {pos_count} positivi")
print(f"scale_pos_weight: {scale_pos_weight:.2f}\n")

model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    max_depth=6,
    learning_rate=0.1,
    n_estimators=200,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=scale_pos_weight,
    random_state=42,
    tree_method='hist',
    n_jobs=-1
)

# Usa validation set per monitoraggio (non il test set!)
model.fit(
    X_train_final, y_train_final,
    eval_set=[(X_val, y_val)],
    verbose=True
)

print("\nTraining completato!")
print("⚠️ Il validation set è stato usato solo per monitorare il training.")
print("   Il test set rimane intoccato per la valutazione finale.")
# Out:
# Training XGBoost per classificazione binaria...
#
# Class imbalance: 80313 negativi vs 80314 positivi
# scale_pos_weight: 1.00
#
# [0]	validation_0-auc:0.89095
# [1]	validation_0-auc:0.89208
# [2]	validation_0-auc:0.89451
# [1]	validation_0-auc:0.89208
# [2]	validation_0-auc:0.89451
# [3]	validation_0-auc:0.89449
# [4]	validation_0-auc:0.89435
# [5]	validation_0-auc:0.89522
# [6]	validation_0-auc:0.89535
# [7]	validation_0-auc:0.89568
# [8]	validation_0-auc:0.89700
# [9]	validation_0-auc:0.89720
# [10]	validation_0-auc:0.89815
# [11]	validation_0-auc:0.89826
# [12]	validation_0-auc:0.89818
# [13]	validation_0-auc:0.89801
# [14]	validation_0-auc:0.89865
# [15]	validation_0-auc:0.89876
# [16]	validation_0-auc:0.89904
# [17]	validation_0-auc:0.89897
# [18]	validation_0-auc:0.89903
# [19]	validation_0-auc:0.89907
# [20]	validation_0-auc:0.89931
# [21]	validation_0-auc:0.89947
# [22]	validation_0-auc:0.89955
# [23]	validation_0-auc:0.90031
# [24]	validation_0-auc:0.90084
# [25]	validation_0-auc:0.90123
# [26]	validation_0-auc:0.90143
# [27]	validation_0-auc:0.90170
# [28]	validation_0-auc:0.90191
# [29]	validation_0-auc:0.90234
# [30]	validation_0-auc:0.90250
# [31]	validation_0-auc:0.90275
# [32]	validation_0-auc:0.90292
# [33]	validation_0-auc:0.90305
# [34]	validation_0-auc:0.90331
# [35]	validation_0-auc:0.90348
# [36]	validation_0-auc:0.90369
# [37]	validation_0-auc:0.90380
# [38]	validation_0-auc:0.90397
# [39]	validation_0-auc:0.90420
# [40]	validation_0-auc:0.90430
# [41]	validation_0-auc:0.90445
# [42]	validation_0-auc:0.90454
# [43]	validation_0-auc:0.90464
# [44]	validation_0-auc:0.90472
# [45]	validation_0-auc:0.90516
# [46]	validation_0-auc:0.90528
# [47]	validation_0-auc:0.90532
# [48]	validation_0-auc:0.90558
# [49]	validation_0-auc:0.90571
# [50]	validation_0-auc:0.90581
# [51]	validation_0-auc:0.90586
# [52]	validation_0-auc:0.90623
# [53]	validation_0-auc:0.90640
# [54]	validation_0-auc:0.90648
# [55]	validation_0-auc:0.90669
# [56]	validation_0-auc:0.90670
# [57]	validation_0-auc:0.90687
# [58]	validation_0-auc:0.90696
# [59]	validation_0-auc:0.90701
# [60]	validation_0-auc:0.90717
# [61]	validation_0-auc:0.90722
# [62]	validation_0-auc:0.90758
# [63]	validation_0-auc:0.90763
# [64]	validation_0-auc:0.90768
# [65]	validation_0-auc:0.90778
# [66]	validation_0-auc:0.90787
# [67]	validation_0-auc:0.90800
# [68]	validation_0-auc:0.90809
# [69]	validation_0-auc:0.90813
# [70]	validation_0-auc:0.90852
# [71]	validation_0-auc:0.90870
# [72]	validation_0-auc:0.90884
# [73]	validation_0-auc:0.90893
# [74]	validation_0-auc:0.90905
# [75]	validation_0-auc:0.90907
# [76]	validation_0-auc:0.90937
# [77]	validation_0-auc:0.90944
# [78]	validation_0-auc:0.90953
# [79]	validation_0-auc:0.90967
# [80]	validation_0-auc:0.90984
# [81]	validation_0-auc:0.91008
# [82]	validation_0-auc:0.91018
# [83]	validation_0-auc:0.91038
# [84]	validation_0-auc:0.91050
# [85]	validation_0-auc:0.91060
# [86]	validation_0-auc:0.91069
# [87]	validation_0-auc:0.91078
# [88]	validation_0-auc:0.91086
# [89]	validation_0-auc:0.91089
# [90]	validation_0-auc:0.91108
# [91]	validation_0-auc:0.91118
# [92]	validation_0-auc:0.91121
# [93]	validation_0-auc:0.91122
# [94]	validation_0-auc:0.91131
# [95]	validation_0-auc:0.91144
# [96]	validation_0-auc:0.91159
# [97]	validation_0-auc:0.91167
# [98]	validation_0-auc:0.91180
# [99]	validation_0-auc:0.91185
# [100]	validation_0-auc:0.91207
# [101]	validation_0-auc:0.91225
# [102]	validation_0-auc:0.91240
# [103]	validation_0-auc:0.91244
# [104]	validation_0-auc:0.91252
# [105]	validation_0-auc:0.91261
# [106]	validation_0-auc:0.91272
# [107]	validation_0-auc:0.91275
# [108]	validation_0-auc:0.91279
# [109]	validation_0-auc:0.91288
# [110]	validation_0-auc:0.91292
# [111]	validation_0-auc:0.91299
# [112]	validation_0-auc:0.91308
# [113]	validation_0-auc:0.91310
# [114]	validation_0-auc:0.91315
# [115]	validation_0-auc:0.91332
# [116]	validation_0-auc:0.91333
# [117]	validation_0-auc:0.91338
# [118]	validation_0-auc:0.91343
# [119]	validation_0-auc:0.91355
# [120]	validation_0-auc:0.91357
# [121]	validation_0-auc:0.91364
# [122]	validation_0-auc:0.91376
# [123]	validation_0-auc:0.91387
# [124]	validation_0-auc:0.91395
# [125]	validation_0-auc:0.91399
# [126]	validation_0-auc:0.91417
# [127]	validation_0-auc:0.91429
# [128]	validation_0-auc:0.91432
# [129]	validation_0-auc:0.91443
# [130]	validation_0-auc:0.91453
# [131]	validation_0-auc:0.91456
# [132]	validation_0-auc:0.91464
# [133]	validation_0-auc:0.91473
# [134]	validation_0-auc:0.91477
# [135]	validation_0-auc:0.91498
# [136]	validation_0-auc:0.91503
# [137]	validation_0-auc:0.91506
# [138]	validation_0-auc:0.91510
# [139]	validation_0-auc:0.91519
# [140]	validation_0-auc:0.91521
# [141]	validation_0-auc:0.91526
# [142]	validation_0-auc:0.91532
# [143]	validation_0-auc:0.91538
# [144]	validation_0-auc:0.91540
# [145]	validation_0-auc:0.91542
# [146]	validation_0-auc:0.91547
# [147]	validation_0-auc:0.91549
# [148]	validation_0-auc:0.91551
# [149]	validation_0-auc:0.91556
# [150]	validation_0-auc:0.91567
# [151]	validation_0-auc:0.91570
# [152]	validation_0-auc:0.91573
# [153]	validation_0-auc:0.91575
# [154]	validation_0-auc:0.91577
# [155]	validation_0-auc:0.91582
# [156]	validation_0-auc:0.91582
# [157]	validation_0-auc:0.91585
# [158]	validation_0-auc:0.91587
# [159]	validation_0-auc:0.91600
# [160]	validation_0-auc:0.91601
# [161]	validation_0-auc:0.91610
# [162]	validation_0-auc:0.91611
# [163]	validation_0-auc:0.91613
# [164]	validation_0-auc:0.91616
# [165]	validation_0-auc:0.91617
# [166]	validation_0-auc:0.91619
# [167]	validation_0-auc:0.91620
# [168]	validation_0-auc:0.91621
# [169]	validation_0-auc:0.91624
# [170]	validation_0-auc:0.91629
# [171]	validation_0-auc:0.91639
# [172]	validation_0-auc:0.91643
# [173]	validation_0-auc:0.91652
# [174]	validation_0-auc:0.91664
# [175]	validation_0-auc:0.91671
# [176]	validation_0-auc:0.91677
# [177]	validation_0-auc:0.91680
# [178]	validation_0-auc:0.91685
# [179]	validation_0-auc:0.91687
# [180]	validation_0-auc:0.91694
# [181]	validation_0-auc:0.91703
# [182]	validation_0-auc:0.91704
# [183]	validation_0-auc:0.91710
# [184]	validation_0-auc:0.91711
# [185]	validation_0-auc:0.91721
# [186]	validation_0-auc:0.91719
# [187]	validation_0-auc:0.91729
# [188]	validation_0-auc:0.91732
# [189]	validation_0-auc:0.91739
# [190]	validation_0-auc:0.91744
# [191]	validation_0-auc:0.91747
# [192]	validation_0-auc:0.91752
# [193]	validation_0-auc:0.91754
# [194]	validation_0-auc:0.91756
# [195]	validation_0-auc:0.91758
# [196]	validation_0-auc:0.91763
# [197]	validation_0-auc:0.91766
# [198]	validation_0-auc:0.91766
# [199]	validation_0-auc:0.91778
#
# Training completato!
# ⚠️ Il validation set è stato usato solo per monitorare il training.
#    Il test set rimane intoccato per la valutazione finale.

# %% [markdown]
# ## 4. Valutazione Performance

# %%
# Predizioni
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]

print("=" * 70)
print("PERFORMANCE TEST SET")
print("=" * 70)

print("\nClassification Report:")
print(classification_report(
    y_test, y_pred,
    target_names=['Non-TP (0)', 'TruePositive (1)'],
    digits=4
))

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print(f"\nACCURACY:          {accuracy:.4f}")
print(f"PRECISION:         {precision:.4f}")
print(f"RECALL:            {recall:.4f}")
print(f"F1-SCORE:          {f1:.4f}")
print(f"ROC AUC:           {roc_auc:.4f}")
# Out:
# ======================================================================
# PERFORMANCE TEST SET
# ======================================================================
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#       Non-TP (0)     0.9211    0.7972    0.8547    105987
# TruePositive (1)     0.4995    0.7475    0.5988     28684
#
#         accuracy                         0.7867    134671
#        macro avg     0.7103    0.7724    0.7268    134671
#     weighted avg     0.8313    0.7867    0.8002    134671
#
#
# ACCURACY:          0.7867
# PRECISION:         0.4995
# RECALL:            0.7475
# F1-SCORE:          0.5988
# ROC AUC:           0.8745

# %% [markdown]
# ## 5. Confusion Matrix

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-TP (0)', 'TruePositive (1)'],
            yticklabels=['Non-TP (0)', 'TruePositive (1)'],
            ax=axes[0])
axes[0].set_title('Confusion Matrix (Counts)')
axes[0].set_ylabel('True Label')
axes[0].set_xlabel('Predicted Label')

sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=['Non-TP (0)', 'TruePositive (1)'],
            yticklabels=['Non-TP (0)', 'TruePositive (1)'],
            ax=axes[1])
axes[1].set_title('Confusion Matrix (Normalized)')
axes[1].set_ylabel('True Label')
axes[1].set_xlabel('Predicted Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. ROC Curve

# %%
# Calcola ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(10, 8))

plt.plot(fpr, tpr, color='blue', lw=2,
         label=f'XGBoost v2 (AUC = {roc_auc:.4f})')

# Plot diagonal (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=1, label='Random Classifier')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve - XGBoost Binary Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=11)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\n📊 ROC AUC Score: {roc_auc:.4f}")
# Out:
# 📊 ROC AUC Score: 0.8745

# %% [markdown]
# ## 7. Cross-Validation

# %%
print("Esecuzione 5-Fold Stratified Cross-Validation...\n")

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Cross-validation con ROC AUC (su X_train completo, non solo train_final)
cv_scores = cross_val_score(
    model, X_train, y_train,
    cv=skf,
    scoring='roc_auc',
    n_jobs=-1
)

print(f"Cross-Validation ROC AUC Scores:")
for i, score in enumerate(cv_scores, 1):
    print(f"  Fold {i}: {score:.4f}")

print(f"\nMedia:  {cv_scores.mean():.4f}")
print(f"Std:    {cv_scores.std():.4f}")
# Out:
# Esecuzione 5-Fold Stratified Cross-Validation...
#
# Cross-Validation ROC AUC Scores:
#   Fold 1: 0.9165
#   Fold 2: 0.9183
#   Fold 3: 0.9167
#   Fold 4: 0.9155
#   Fold 5: 0.9173
#
# Media:  0.9169
# Std:    0.0009

# %% [markdown]
# ## 8. Feature Importance

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train_final.columns,
    'Importance': model.feature_importances_
}).sort_values('Importance', ascending=False)

print("Top 30 Features più importanti:")
print(feature_importance.head(30).to_string(index=False))
# Out:
# Top 30 Features più importanti:
#                       Feature  Importance
#              SmoothedRisk_avg    0.271961
#                     T1078_sum    0.190686
#      EvidenceRole_Related_sum    0.052019
#               Roles_freq_mean    0.042778
#          EntityType_freq_mean    0.036946
#               GeoLoc_freq_avg    0.036189
#                  NumEvidences    0.028858
#    SuspicionLevel_Missing_sum    0.028046
#            Category_freq_mean    0.022533
# SuspicionLevel_Suspicious_sum    0.020775
#                     T1566_sum    0.019460
#   AntispamDirection_freq_mean    0.017947
#         LastVerdict_freq_mean    0.017849
#                 IsWeekend_max    0.014053
#              Duration_seconds    0.012815
#                     T1012_sum    0.012504
#                month_get_mode    0.011843
#                     NumAlerts    0.010041
#       ActionGrouped_freq_mean    0.009440
#        ThreatFamily_freq_mean    0.008600
#      ActionGranular_freq_mean    0.008524
#                     T1110_sum    0.008392
#        ResourceType_freq_mean    0.007948
#              weekday_get_mode    0.007757
#                     T1048_sum    0.007602
#                     T1568_sum    0.006803
#                     T1008_sum    0.006643
#                     T1098_sum    0.006552
#                     T1003_sum    0.006460
#                     T1046_sum    0.005740

# %%
# Plot top features
plt.figure(figsize=(12, 10))
top_n = 25
top_features = feature_importance.head(top_n)

plt.barh(range(top_n), top_features['Importance'], color='steelblue')
plt.yticks(range(top_n), top_features['Feature'])
plt.xlabel('Importance', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.title(f'Top {top_n} Feature Importance - XGBoost v2', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Salvataggio Modello

# %%
# Crea cartella per XGBoost v2
model_dir = '../models/xgboost_v2'
os.makedirs(model_dir, exist_ok=True)

# Salva modello
model.save_model(f'{model_dir}/model.json')

with open(f'{model_dir}/model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Salva feature importance
feature_importance.to_csv(f'{model_dir}/feature_importance.csv', index=False)

# Salva metriche complete
metrics = {
    'model_name': 'XGBoost_v2_Binary',
    'timestamp': datetime.now().isoformat(),
    'dataset_version': 'processed_v4_hybrid',
    'target': 'BinaryIncidentGrade (0=Non-TP, 1=TP)',
    'test_accuracy': float(accuracy),
    'test_precision': float(precision),
    'test_recall': float(recall),
    'test_f1_score': float(f1),
    'test_roc_auc': float(roc_auc),
    'cv_roc_auc_mean': float(cv_scores.mean()),
    'cv_roc_auc_std': float(cv_scores.std()),
    'n_features': int(X_train_final.shape[1]),
    'n_train_samples': int(len(X_train_final)),
    'n_val_samples': int(len(X_val)),
    'n_test_samples': int(len(X_test)),
    'class_distribution_train': {
        'class_0': int((y_train_final == 0).sum()),
        'class_1': int((y_train_final == 1).sum())
    },
    'hyperparameters': {
        'objective': 'binary:logistic',
        'max_depth': model.max_depth,
        'learning_rate': float(model.learning_rate),
        'n_estimators': model.n_estimators,
        'subsample': float(model.subsample),
        'colsample_bytree': float(model.colsample_bytree),
        'scale_pos_weight': float(scale_pos_weight)
    },
    'top_10_features': feature_importance.head(10)[['Feature', 'Importance']].to_dict('records'),
    'note': 'Validation set (20% of train) used for eval_set monitoring. Test set used only for final evaluation.'
}

with open(f'{model_dir}/metrics.json', 'w') as f:
    json.dump(metrics, f, indent=2)

print(f"\n{'='*70}")
print(f"Modello salvato in {model_dir}/")
print(f"{'='*70}")
print("  ✓ model.json")
print("  ✓ model.pkl")
print("  ✓ feature_importance.csv")
print("  ✓ metrics.json")
print(f"\n📊 ROC AUC Test: {roc_auc:.4f}")
print(f"📊 ROC AUC CV:   {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
# Out:
# ======================================================================
# Modello salvato in ../models/xgboost_v2/
# ======================================================================
#   ✓ model.json
#   ✓ model.pkl
#   ✓ feature_importance.csv
#   ✓ metrics.json
#
# 📊 ROC AUC Test: 0.8745
# 📊 ROC AUC CV:   0.9169 ± 0.0009

# %% [markdown]
# ## Summary
#
# **Modello:** XGBoost Binary Classifier
# **Dataset:** processed_v3 (SmoothedRisk, GeoLoc_freq, frequency encoding)
# **Target:** BinaryIncidentGrade (0=FalsePositive/BenignPositive, 1=TruePositive)
#
# **Features chiave del v3:**
# - SmoothedRisk (Bayesian smoothing per AlertTitle)
# - GeoLoc_freq (frequenza location)
# - Frequency encoding per colonne ad alta cardinalità
# - MITRE top 30 techniques
#
# **Metriche principali:**
# - ROC AUC (primary metric per binary classification)
# - Precision/Recall/F1 per valutare trade-off
# - Cross-validation per robustezza
