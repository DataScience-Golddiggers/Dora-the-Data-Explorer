# %% [markdown]
# # XGBoost v2 - Binary Classification
#
# **Obiettivo:** Classificazione binaria IncidentGrade (1=TruePositive, 0=FalsePositive/BenignPositive)
#
# **Dataset:** Processed v3 con SmoothedRisk, GeoLoc_freq, frequency encoding
#
# **Metriche:** ROC AUC, Accuracy, Precision, Recall, F1-Score
#
# **Pipeline:**
# 1. Caricamento dati processed_v3
# 2. Training XGBoost (binary classification)
# 3. Valutazione e cross-validation
# 4. ROC Curve e AUC
# 5. Feature importance
# 6. Salvataggio modello in models/xgboost_v2/

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    roc_auc_score,
    roc_curve,
    accuracy_score,
    f1_score,
    precision_score,
    recall_score
)
from sklearn.model_selection import cross_val_score, StratifiedKFold
import pickle
import os
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('whitegrid')

print("Librerie importate con successo!")
# Out:
# Librerie importate con successo!

# %% [markdown]
# ## 2. Caricamento Dati

# %%
print("Caricamento dataset processed_v4_hybrid...")

X_train = pd.read_csv('../data/processed_v4_hybrid/X_train.csv')
X_test = pd.read_csv('../data/processed_v4_hybrid/X_test.csv')
y_train = pd.read_csv('../data/processed_v4_hybrid/y_train.csv')['BinaryIncidentGrade']
y_test = pd.read_csv('../data/processed_v4_hybrid/y_test.csv')['BinaryIncidentGrade']

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"\nDistribuzione y_train:")
print(y_train.value_counts(normalize=True))
print(f"\nDistribuzione y_test:")
print(y_test.value_counts(normalize=True))
# Out:
# Caricamento dataset processed_v4_hybrid...
# X_train: (304848, 43)
# X_test: (149537, 43)
#
# Distribuzione y_train:
# BinaryIncidentGrade
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
# Distribuzione y_test:
# BinaryIncidentGrade
# 0    0.708768
# 1    0.291232
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

print("Creazione validation set (20% del training set)...\n")

# Split training in train e validation (stratificato)
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train, y_train,
    test_size=0.2,
    stratify=y_train,
    random_state=42
)

print(f"X_train_final: {X_train_final.shape}")
print(f"X_val:         {X_val.shape}")
print(f"X_test:        {X_test.shape}")

print(f"\nDistribuzione y_train_final:")
print(y_train_final.value_counts(normalize=True))
print(f"\nDistribuzione y_val:")
print(y_val.value_counts(normalize=True))

print("\n✅ Validation set creato. Verrà usato per monitorare il training.")
# Out:
# Creazione validation set (20% del training set)...
#
# X_train_final: (243878, 43)
# X_val:         (60970, 43)
# X_test:        (149537, 43)
#
# Distribuzione y_train_final:
# BinaryIncidentGrade
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
# Distribuzione y_val:
# BinaryIncidentGrade
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
# ✅ Validation set creato. Verrà usato per monitorare il training.

# %% [markdown]
# ## 2.1. Creazione Validation Set

# %% [markdown]
# ## 3. Training XGBoost (Binary Classification)

# %%
print("Training XGBoost per classificazione binaria...\n")

# Calcola scale_pos_weight per gestire imbalance (su train_final)
neg_count = (y_train_final == 0).sum()
pos_count = (y_train_final == 1).sum()
scale_pos_weight = neg_count / pos_count

print(f"Class imbalance: {neg_count} negativi vs {pos_count} positivi")
print(f"scale_pos_weight: {scale_pos_weight:.2f}\n")

model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    max_depth=6,
    learning_rate=0.1,
    n_estimators=200,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=scale_pos_weight,
    random_state=42,
    tree_method='hist',
    n_jobs=-1
)

# Usa validation set per monitoraggio (non il test set!)
model.fit(
    X_train_final, y_train_final,
    eval_set=[(X_val, y_val)],
    verbose=True
)

print("\nTraining completato!")
print("⚠️ Il validation set è stato usato solo per monitorare il training.")
print("   Il test set rimane intoccato per la valutazione finale.")
# Out:
# Training XGBoost per classificazione binaria...
#
# Class imbalance: 121939 negativi vs 121939 positivi
# scale_pos_weight: 1.00
#
# [0]	validation_0-auc:0.90985
# [1]	validation_0-auc:0.91025
# [2]	validation_0-auc:0.91800
# [3]	validation_0-auc:0.92019
# [4]	validation_0-auc:0.91924
# [5]	validation_0-auc:0.92094
# [6]	validation_0-auc:0.92127
# [7]	validation_0-auc:0.92317
# [8]	validation_0-auc:0.92378
# [9]	validation_0-auc:0.92444
# [10]	validation_0-auc:0.92494
# [11]	validation_0-auc:0.92541
# [12]	validation_0-auc:0.92604
# [13]	validation_0-auc:0.92668
# [14]	validation_0-auc:0.92699
# [15]	validation_0-auc:0.92744
# [16]	validation_0-auc:0.92782
# [17]	validation_0-auc:0.92807
# [18]	validation_0-auc:0.92828
# [19]	validation_0-auc:0.92831
# [20]	validation_0-auc:0.92836
# [21]	validation_0-auc:0.92859
# [22]	validation_0-auc:0.92877
# [23]	validation_0-auc:0.92928
# [24]	validation_0-auc:0.92977
# [25]	validation_0-auc:0.93009
# [26]	validation_0-auc:0.93024
# [27]	validation_0-auc:0.93033
# [28]	validation_0-auc:0.93031
# [29]	validation_0-auc:0.93035
# [30]	validation_0-auc:0.93065
# [31]	validation_0-auc:0.93097
# [32]	validation_0-auc:0.93101
# [33]	validation_0-auc:0.93101
# [34]	validation_0-auc:0.93121
# [35]	validation_0-auc:0.93154
# [36]	validation_0-auc:0.93163
# [37]	validation_0-auc:0.93162
# [38]	validation_0-auc:0.93186
# [39]	validation_0-auc:0.93193
# [40]	validation_0-auc:0.93200
# [41]	validation_0-auc:0.93203
# [42]	validation_0-auc:0.93214
# [43]	validation_0-auc:0.93236
# [44]	validation_0-auc:0.93239
# [45]	validation_0-auc:0.93251
# [46]	validation_0-auc:0.93261
# [47]	validation_0-auc:0.93262
# [48]	validation_0-auc:0.93267
# [49]	validation_0-auc:0.93284
# [50]	validation_0-auc:0.93287
# [51]	validation_0-auc:0.93292
# [52]	validation_0-auc:0.93299
# [53]	validation_0-auc:0.93313
# [54]	validation_0-auc:0.93327
# [55]	validation_0-auc:0.93334
# [56]	validation_0-auc:0.93335
# [57]	validation_0-auc:0.93364
# [58]	validation_0-auc:0.93374
# [59]	validation_0-auc:0.93381
# [60]	validation_0-auc:0.93398
# [61]	validation_0-auc:0.93403
# [62]	validation_0-auc:0.93407
# [63]	validation_0-auc:0.93411
# [64]	validation_0-auc:0.93426
# [65]	validation_0-auc:0.93442
# [66]	validation_0-auc:0.93470
# [67]	validation_0-auc:0.93473
# [68]	validation_0-auc:0.93509
# [69]	validation_0-auc:0.93521
# [70]	validation_0-auc:0.93560
# [71]	validation_0-auc:0.93566
# [72]	validation_0-auc:0.93595
# [73]	validation_0-auc:0.93615
# [74]	validation_0-auc:0.93656
# [75]	validation_0-auc:0.93665
# [76]	validation_0-auc:0.93673
# [77]	validation_0-auc:0.93676
# [78]	validation_0-auc:0.93680
# [79]	validation_0-auc:0.93703
# [80]	validation_0-auc:0.93707
# [81]	validation_0-auc:0.93729
# [82]	validation_0-auc:0.93742
# [83]	validation_0-auc:0.93759
# [84]	validation_0-auc:0.93781
# [85]	validation_0-auc:0.93808
# [86]	validation_0-auc:0.93825
# [87]	validation_0-auc:0.93828
# [88]	validation_0-auc:0.93835
# [89]	validation_0-auc:0.93840
# [90]	validation_0-auc:0.93853
# [91]	validation_0-auc:0.93859
# [92]	validation_0-auc:0.93862
# [93]	validation_0-auc:0.93873
# [94]	validation_0-auc:0.93876
# [95]	validation_0-auc:0.93886
# [96]	validation_0-auc:0.93894
# [97]	validation_0-auc:0.93899
# [98]	validation_0-auc:0.93900
# [99]	validation_0-auc:0.93907
# [100]	validation_0-auc:0.93917
# [101]	validation_0-auc:0.93927
# [102]	validation_0-auc:0.93941
# [103]	validation_0-auc:0.93949
# [104]	validation_0-auc:0.93950
# [105]	validation_0-auc:0.93967
# [106]	validation_0-auc:0.93972
# [107]	validation_0-auc:0.93980
# [108]	validation_0-auc:0.93988
# [109]	validation_0-auc:0.94001
# [110]	validation_0-auc:0.94003
# [111]	validation_0-auc:0.94007
# [112]	validation_0-auc:0.94014
# [113]	validation_0-auc:0.94015
# [114]	validation_0-auc:0.94029
# [115]	validation_0-auc:0.94038
# [116]	validation_0-auc:0.94043
# [117]	validation_0-auc:0.94048
# [118]	validation_0-auc:0.94048
# [119]	validation_0-auc:0.94070
# [120]	validation_0-auc:0.94075
# [121]	validation_0-auc:0.94082
# [122]	validation_0-auc:0.94082
# [123]	validation_0-auc:0.94091
# [124]	validation_0-auc:0.94095
# [125]	validation_0-auc:0.94108
# [126]	validation_0-auc:0.94115
# [127]	validation_0-auc:0.94116
# [128]	validation_0-auc:0.94118
# [129]	validation_0-auc:0.94122
# [130]	validation_0-auc:0.94126
# [131]	validation_0-auc:0.94134
# [132]	validation_0-auc:0.94143
# [133]	validation_0-auc:0.94149
# [134]	validation_0-auc:0.94153
# [135]	validation_0-auc:0.94157
# [136]	validation_0-auc:0.94164
# [137]	validation_0-auc:0.94164
# [138]	validation_0-auc:0.94169
# [139]	validation_0-auc:0.94174
# [140]	validation_0-auc:0.94176
# [141]	validation_0-auc:0.94183
# [142]	validation_0-auc:0.94184
# [143]	validation_0-auc:0.94190
# [144]	validation_0-auc:0.94192
# [145]	validation_0-auc:0.94202
# [146]	validation_0-auc:0.94205
# [147]	validation_0-auc:0.94206
# [148]	validation_0-auc:0.94216
# [149]	validation_0-auc:0.94217
# [150]	validation_0-auc:0.94221
# [151]	validation_0-auc:0.94221
# [152]	validation_0-auc:0.94226
# [153]	validation_0-auc:0.94227
# [154]	validation_0-auc:0.94238
# [155]	validation_0-auc:0.94246
# [156]	validation_0-auc:0.94256
# [157]	validation_0-auc:0.94258
# [158]	validation_0-auc:0.94259
# [159]	validation_0-auc:0.94267
# [160]	validation_0-auc:0.94269
# [161]	validation_0-auc:0.94272
# [162]	validation_0-auc:0.94277
# [163]	validation_0-auc:0.94282
# [164]	validation_0-auc:0.94287
# [165]	validation_0-auc:0.94289
# [166]	validation_0-auc:0.94294
# [167]	validation_0-auc:0.94296
# [168]	validation_0-auc:0.94309
# [169]	validation_0-auc:0.94314
# [170]	validation_0-auc:0.94315
# [171]	validation_0-auc:0.94319
# [172]	validation_0-auc:0.94322
# [173]	validation_0-auc:0.94327
# [174]	validation_0-auc:0.94338
# [175]	validation_0-auc:0.94338
# [176]	validation_0-auc:0.94346
# [177]	validation_0-auc:0.94351
# [178]	validation_0-auc:0.94351
# [179]	validation_0-auc:0.94352
# [180]	validation_0-auc:0.94356
# [181]	validation_0-auc:0.94357
# [182]	validation_0-auc:0.94363
# [183]	validation_0-auc:0.94363
# [184]	validation_0-auc:0.94366
# [185]	validation_0-auc:0.94367
# [186]	validation_0-auc:0.94374
# [187]	validation_0-auc:0.94374
# [188]	validation_0-auc:0.94377
# [189]	validation_0-auc:0.94385
# [190]	validation_0-auc:0.94386
# [191]	validation_0-auc:0.94387
# [192]	validation_0-auc:0.94389
# [193]	validation_0-auc:0.94390
# [194]	validation_0-auc:0.94397
# [195]	validation_0-auc:0.94398
# [196]	validation_0-auc:0.94402
# [197]	validation_0-auc:0.94404
# [198]	validation_0-auc:0.94405
# [199]	validation_0-auc:0.94407
#
# Training completato!
# ⚠️ Il validation set è stato usato solo per monitorare il training.
#    Il test set rimane intoccato per la valutazione finale.

# %% [markdown]
# ## 4. Valutazione Performance

# %%
# Predizioni
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]

print("=" * 70)
print("PERFORMANCE TEST SET")
print("=" * 70)

print("\nClassification Report:")
print(classification_report(
    y_test, y_pred,
    target_names=['Non-TP (0)', 'TruePositive (1)'],
    digits=4
))

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print(f"\nACCURACY:          {accuracy:.4f}")
print(f"PRECISION:         {precision:.4f}")
print(f"RECALL:            {recall:.4f}")
print(f"F1-SCORE:          {f1:.4f}")
print(f"ROC AUC:           {roc_auc:.4f}")
# Out:
# ======================================================================
# PERFORMANCE TEST SET
# ======================================================================
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#       Non-TP (0)     0.9016    0.9303    0.9157    105987
# TruePositive (1)     0.8161    0.7530    0.7833     43550
#
#         accuracy                         0.8786    149537
#        macro avg     0.8588    0.8416    0.8495    149537
#     weighted avg     0.8767    0.8786    0.8771    149537
#
#
# ACCURACY:          0.8786
# PRECISION:         0.8161
# RECALL:            0.7530
# F1-SCORE:          0.7833
# ROC AUC:           0.9307

# %% [markdown]
# ## 5. Confusion Matrix

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-TP (0)', 'TruePositive (1)'],
            yticklabels=['Non-TP (0)', 'TruePositive (1)'],
            ax=axes[0])
axes[0].set_title('Confusion Matrix (Counts)')
axes[0].set_ylabel('True Label')
axes[0].set_xlabel('Predicted Label')

sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=['Non-TP (0)', 'TruePositive (1)'],
            yticklabels=['Non-TP (0)', 'TruePositive (1)'],
            ax=axes[1])
axes[1].set_title('Confusion Matrix (Normalized)')
axes[1].set_ylabel('True Label')
axes[1].set_xlabel('Predicted Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. ROC Curve

# %%
# Calcola ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(10, 8))

plt.plot(fpr, tpr, color='blue', lw=2,
         label=f'XGBoost v2 (AUC = {roc_auc:.4f})')

# Plot diagonal (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=1, label='Random Classifier')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve - XGBoost Binary Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=11)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\n📊 ROC AUC Score: {roc_auc:.4f}")
# Out:
# 📊 ROC AUC Score: 0.9307

# %% [markdown]
# ## 7. Cross-Validation

# %%
print("Esecuzione 5-Fold Stratified Cross-Validation...\n")

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Cross-validation con ROC AUC (su X_train completo, non solo train_final)
cv_scores = cross_val_score(
    model, X_train, y_train,
    cv=skf,
    scoring='roc_auc',
    n_jobs=-1
)

print(f"Cross-Validation ROC AUC Scores:")
for i, score in enumerate(cv_scores, 1):
    print(f"  Fold {i}: {score:.4f}")

print(f"\nMedia:  {cv_scores.mean():.4f}")
print(f"Std:    {cv_scores.std():.4f}")
# Out:
# Esecuzione 5-Fold Stratified Cross-Validation...
#
# Cross-Validation ROC AUC Scores:
#   Fold 1: 0.9436
#   Fold 2: 0.9453
#   Fold 3: 0.9421
#   Fold 4: 0.9421
#   Fold 5: 0.9440
#
# Media:  0.9434
# Std:    0.0012

# %% [markdown]
# ## 8. Feature Importance

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train_final.columns,
    'Importance': model.feature_importances_
}).sort_values('Importance', ascending=False)

print("Top 30 Features più importanti:")
print(feature_importance.head(30).to_string(index=False))
# Out:
# Top 30 Features più importanti:
#                       Feature  Importance
#        ResourceType_freq_mean    0.330654
#      ActionGranular_freq_mean    0.246145
#       ActionGrouped_freq_mean    0.230611
#               Roles_freq_mean    0.053303
#              SmoothedRisk_avg    0.032188
#                     T1078_sum    0.019661
#        ThreatFamily_freq_mean    0.011508
#               GeoLoc_freq_avg    0.009900
#         LastVerdict_freq_mean    0.009739
#   AntispamDirection_freq_mean    0.004800
#          EntityType_freq_mean    0.003623
#            Category_freq_mean    0.003548
#    SuspicionLevel_Missing_sum    0.003513
#                     T1566_sum    0.002808
#                     T1106_sum    0.002754
#                  NumEvidences    0.002740
#                     T1046_sum    0.002470
#              Duration_seconds    0.002378
# SuspicionLevel_Suspicious_sum    0.002337
#      EvidenceRole_Related_sum    0.002125
#                     NumAlerts    0.001550
#                month_get_mode    0.001469
#                 IsWeekend_max    0.001465
#                     T1210_sum    0.001426
#                     T1012_sum    0.001410
#                     T1008_sum    0.001390
#                     T1559_sum    0.001381
#                     T1110_sum    0.001363
#              weekday_get_mode    0.001227
#                     T1048_sum    0.001161

# %%
# Plot top features
plt.figure(figsize=(12, 10))
top_n = 25
top_features = feature_importance.head(top_n)

plt.barh(range(top_n), top_features['Importance'], color='steelblue')
plt.yticks(range(top_n), top_features['Feature'])
plt.xlabel('Importance', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.title(f'Top {top_n} Feature Importance - XGBoost v2', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Salvataggio Modello

# %%
# Crea cartella per XGBoost v2
model_dir = '../models/xgboost_v2'
os.makedirs(model_dir, exist_ok=True)

# Salva modello
model.save_model(f'{model_dir}/model.json')

with open(f'{model_dir}/model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Salva feature importance
feature_importance.to_csv(f'{model_dir}/feature_importance.csv', index=False)

# Salva metriche complete
metrics = {
    'model_name': 'XGBoost_v2_Binary',
    'timestamp': datetime.now().isoformat(),
    'dataset_version': 'processed_v4_hybrid',
    'target': 'BinaryIncidentGrade (0=Non-TP, 1=TP)',
    'test_accuracy': float(accuracy),
    'test_precision': float(precision),
    'test_recall': float(recall),
    'test_f1_score': float(f1),
    'test_roc_auc': float(roc_auc),
    'cv_roc_auc_mean': float(cv_scores.mean()),
    'cv_roc_auc_std': float(cv_scores.std()),
    'n_features': int(X_train_final.shape[1]),
    'n_train_samples': int(len(X_train_final)),
    'n_val_samples': int(len(X_val)),
    'n_test_samples': int(len(X_test)),
    'class_distribution_train': {
        'class_0': int((y_train_final == 0).sum()),
        'class_1': int((y_train_final == 1).sum())
    },
    'hyperparameters': {
        'objective': 'binary:logistic',
        'max_depth': model.max_depth,
        'learning_rate': float(model.learning_rate),
        'n_estimators': model.n_estimators,
        'subsample': float(model.subsample),
        'colsample_bytree': float(model.colsample_bytree),
        'scale_pos_weight': float(scale_pos_weight)
    },
    'top_10_features': feature_importance.head(10)[['Feature', 'Importance']].to_dict('records'),
    'note': 'Validation set (20% of train) used for eval_set monitoring. Test set used only for final evaluation.'
}

with open(f'{model_dir}/metrics.json', 'w') as f:
    json.dump(metrics, f, indent=2)

print(f"\n{'='*70}")
print(f"Modello salvato in {model_dir}/")
print(f"{'='*70}")
print("  ✓ model.json")
print("  ✓ model.pkl")
print("  ✓ feature_importance.csv")
print("  ✓ metrics.json")
print(f"\n📊 ROC AUC Test: {roc_auc:.4f}")
print(f"📊 ROC AUC CV:   {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
# Out:
# ======================================================================
# Modello salvato in ../models/xgboost_v2/
# ======================================================================
#   ✓ model.json
#   ✓ model.pkl
#   ✓ feature_importance.csv
#   ✓ metrics.json
#
# 📊 ROC AUC Test: 0.9307
# 📊 ROC AUC CV:   0.9434 ± 0.0012

# %% [markdown]
# ## Summary
#
# **Modello:** XGBoost Binary Classifier
# **Dataset:** processed_v3 (SmoothedRisk, GeoLoc_freq, frequency encoding)
# **Target:** BinaryIncidentGrade (0=FalsePositive/BenignPositive, 1=TruePositive)
#
# **Features chiave del v3:**
# - SmoothedRisk (Bayesian smoothing per AlertTitle)
# - GeoLoc_freq (frequenza location)
# - Frequency encoding per colonne ad alta cardinalità
# - MITRE top 30 techniques
#
# **Metriche principali:**
# - ROC AUC (primary metric per binary classification)
# - Precision/Recall/F1 per valutare trade-off
# - Cross-validation per robustezza
